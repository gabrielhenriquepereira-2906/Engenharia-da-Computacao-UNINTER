# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielhenriquepereira-2906/Engenharia-da-Computacao-UNINTER/blob/main/Aula_02_Pratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. O Ciclo de Processamento de Dados

# %% [markdown]
# ### O Primeiro Programa!

# %% [markdown]
# ---

# %% [markdown]
# > `Olá, mundo!`

# %%
print('Olá, mundo!')
# Out:
# Olá, mundo!

# %% [markdown]
# `Atenção!`

# %%
Print('Olá, mundo!')

# %% [markdown]
# ### Função de Saída

# %% [markdown]
# ---

# %% [markdown]
# `Podemos usar aspas duplas:`

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# `Operações Aritméticas:`

# %%
print(2+3)
# Out:
# 5

# %% [markdown]
# `O que acontece aqui?`

# %%
print('2+3')
# Out:
# 2+3

# %% [markdown]
# `E aqui? Acontece uma concatenação.`

# %%
print('2'+'3')
# Out:
# 23

# %% [markdown]
# `Concatenando mensagens:`

# %%
print('Olá, '+'mundo!')
print('Olá,','mundo!')
# Out:
# Olá, mundo!
# Olá, mundo!

# %% [markdown]
# `Concatenando mensagens e números:`

# %%
print('O resultado da soma de 2 + 3 é:', 2+3)
# Out:
# O resultado da soma de 2 + 3 é: 5

# %% [markdown]
# ### Operadores e operações matemáticas

# %% [markdown]
# ---

# %%
print(10*(5+7)/4)
# Out:
# 30.0

# %% [markdown]
# ``Cuidado!!!``

# %%
print(10*(5+7/4))
# Out:
# 67.5
